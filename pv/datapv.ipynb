# %%
import pandas as pd
df = pd.read_csv("/home/marko/projects/tf216/pv/pv.csv")

# %%
print(list(df.columns))
# Out:
# ['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'DEWP', 'DEWP_ATTRIBUTES', 'FRSHTT', 'FRSHTT_ATTRIBUTES', 'GUST', 'GUST_ATTRIBUTES', 'MAX', 'MAX_ATTRIBUTES', 'MIN', 'MIN_ATTRIBUTES', 'MXSPD', 'MXSPD_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'SLP', 'SLP_ATTRIBUTES', 'SNDP', 'SNDP_ATTRIBUTES', 'STP', 'STP_ATTRIBUTES', 'TEMP', 'TEMP_ATTRIBUTES', 'VISIB', 'VISIB_ATTRIBUTES', 'WDSP', 'WDSP_ATTRIBUTES']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6842 entries, 0 to 6841
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   STATION            6842 non-null   int64
#  1   NAME               6842 non-null   object
#  2   LATITUDE           6842 non-null   float64
#  3   LONGITUDE          6842 non-null   float64
#  4   ELEVATION          6842 non-null   float64
#  5   DATE               6842 non-null   object
#  6   DEWP               6842 non-null   float64
#  7   DEWP_ATTRIBUTES    6842 non-null   int64
#  8   FRSHTT             6842 non-null   int64
#  9   FRSHTT_ATTRIBUTES  0 non-null      float64
#  10  GUST               6842 non-null   float64
#  11  GUST_ATTRIBUTES    0 non-null      float64
#  12  MAX                6842 non-null   float64
#  13  MAX_ATTRIBUTES     6842 non-null   object
#  14  MIN                6842 non-null   float64
#  15  MIN_ATTRIBUTES     6842 non-null   object
#  16  MXSPD              6842 non-null   float64
#  17  MXSPD_ATTRIBUTES   0 non-null      float64
#  18  PRCP               6842 non-null   float64
#  19  PRCP_ATTRIBUTES    6842 non-null   object
#  20  SLP                6842 non-null   float64
#  21  SLP_ATTRIBUTES     6842 non-null   int64
#  22  SNDP               6842 non-null   float64
#  23  SNDP_ATTRIBUTES    0 non-null      float64
#  24  STP                6842 non-null   float64
#  25  STP_ATTRIBUTES     6842 non-null   int64
#  26  TEMP               6842 non-null   float64
#  27  TEMP_ATTRIBUTES    6842 non-null   int64
#  28  VISIB              6842 non-null   float64
#  29  VISIB_ATTRIBUTES   6842 non-null   int64
#  30  WDSP               6842 non-null   float64
#  31  WDSP_ATTRIBUTES    6842 non-null   int64
# dtypes: float64(19), int64(8), object(5)
# memory usage: 1.7+ MB

# %%
df["DATE"] = pd.to_datetime(df["DATE"], format="%Y-%m-%d")

# %%
all_dates = pd.date_range(start=df["DATE"].min(), end=df["DATE"].max(), freq="D")
df = df.set_index("DATE")
df = df.reindex(all_dates)
df = df.reset_index()
df = df.rename(columns={"index": "DATE"})

# %%
df.drop(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'GUST', 'SNDP', 'FRSHTT', 'SLP', 'STP', 'PRCP', 'MXSPD', 'VISIB'], axis=1, inplace=True)
df.drop(['DEWP_ATTRIBUTES', 'FRSHTT_ATTRIBUTES', 'GUST_ATTRIBUTES', 'MAX_ATTRIBUTES', 'MIN_ATTRIBUTES', 'MXSPD_ATTRIBUTES', 'PRCP_ATTRIBUTES', 'SLP_ATTRIBUTES', 'SNDP_ATTRIBUTES', 'STP_ATTRIBUTES', 'TEMP_ATTRIBUTES', 'VISIB_ATTRIBUTES', 'WDSP_ATTRIBUTES'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8401 entries, 0 to 8400
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    8401 non-null   datetime64[ns]
#  1   DEWP    6842 non-null   float64
#  2   MAX     6842 non-null   float64
#  3   MIN     6842 non-null   float64
#  4   TEMP    6842 non-null   float64
#  5   WDSP    6842 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 393.9 KB

# %%
import numpy as np
df['DEWP'] = df['DEWP'].replace(9999.9, np.nan)
df['WDSP'] = df['WDSP'].replace(999.9, np.nan)

# %%
df['MIN'] = df['MIN'].replace(9999.9, np.nan)

# %%
print(df.isna().sum())
# Out:
# DATE       0
# DEWP    1581
# MAX     1559
# MIN     1560
# TEMP    1559
# WDSP    1585
# dtype: int64

# %%
bounds = {
        'TEMP': (df["TEMP"].min(), df["TEMP"].max()),
        'MIN': (df["MIN"].min(), df["MIN"].max()),
        'MAX': (df["MAX"].min(), df["MAX"].max()),
        'DEWP': (df["DEWP"].min(), df["DEWP"].max()),
        'WDSP': (df["WDSP"].min(), df["WDSP"].max())
}

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df.loc[df.index.year == df.index.year.min()] = df.loc[df.index.year == df.index.year.min()].interpolate(method='linear')
for col in ['TEMP', 'MIN', 'MAX', 'DEWP', 'WDSP']:
   df[col] = df.apply(lambda row: 
                       df[(df.index.day == row.name.day) & (df.index.month == row.name.month) & 
                          (df.index.year < row.name.year)][col].mean() 
                       if pd.isna(row[col]) else row[col], axis=1)
df = df.reset_index().rename(columns={"index": "DATE"})

# %%
for col in ['TEMP', 'MIN', 'MAX', 'DEWP', 'WDSP']:
    df[col] = df[col].interpolate(method='linear', limit_direction='forward', axis=0)

# %%
print(bounds)
# Out:
# {'TEMP': (3.2, 87.6), 'MIN': (-10.3, 75.2), 'MAX': (10.8, 100.9), 'DEWP': (-4.6, 68.2), 'WDSP': (0.0, 21.9)}

# %%
for col in ['TEMP', 'MIN', 'MAX', 'DEWP', 'WDSP']:
        low, high = bounds.get(col, (-1000, 1000))
        df[col] = df[col].clip(lower=low, upper=high)

for col in ['TEMP', 'MIN', 'MAX', 'DEWP', 'WDSP']:
        mask = (df[col] > 1000) | (df[col] < -1000)
        df.loc[mask, col] = df[col].rolling(window=3, center=True, min_periods=1).mean()[mask]

# %%
nan_rows = df[df.isna().any(axis=1)]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [DATE, DEWP, MAX, MIN, TEMP, WDSP]
# Index: []

# %%
for col in ['TEMP', 'MIN', 'MAX', 'DEWP', 'WDSP']:
    df[col] = df[col].round(1)
    
for col in ['TEMP', 'MIN', 'MAX', 'DEWP']:
    df[col] = (df[col] - 32) * 5/9
    df[col] = df[col].round(1)
    

df['WDSP'] = df['WDSP'] * 0.514444
df['WDSP'] = df['WDSP'].round(1)
    
def vapor_pressure(T):
    return 6.112 * np.exp((17.62 * T) / (243.12 + T))

df['DEWP'] = vapor_pressure(df['DEWP']) / vapor_pressure(df['TEMP'])
df = df.rename(columns={'DEWP': 'RHUM'})
df['RHUM'] = df['RHUM'].round(3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8401 entries, 0 to 8400
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    8401 non-null   datetime64[ns]
#  1   RHUM    8401 non-null   float64
#  2   MAX     8401 non-null   float64
#  3   MIN     8401 non-null   float64
#  4   TEMP    8401 non-null   float64
#  5   WDSP    8401 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 393.9 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.suptitle("Pljevlja", fontsize=12, y=0.95)
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, annot_kws={"size": 10}) 
plt.show()

# %%
for col in ['TEMP', 'MAX', 'MIN']:
    print(f"Correlations for {col}:")
    print(correlation_matrix[col].abs().sort_values(ascending=False), "\n")
# Out:
# Correlations for TEMP:
# TEMP    1.000000
# MAX     0.962735
# MIN     0.931853
# RHUM    0.587020
# WDSP    0.270639
# DATE    0.104133
# Name: TEMP, dtype: float64
#
# Correlations for MAX:
# MAX     1.000000
# TEMP    0.962735
# MIN     0.839560
# RHUM    0.634631
# WDSP    0.194921
# DATE    0.068136
# Name: MAX, dtype: float64
#
# Correlations for MIN:
# MIN     1.000000
# TEMP    0.931853
# MAX     0.839560
# RHUM    0.347308
# WDSP    0.224612
# DATE    0.063743
# Name: MIN, dtype: float64

# %%
plt.figure(figsize=(12, 4))

plt.suptitle("Pljevlja", fontsize=12, y=0.95)

plt.subplot(1, 3, 1)
sns.histplot(df['TEMP'], bins=20, kde=True, color='green')

plt.subplot(1, 3, 2)
sns.histplot(df['MAX'], bins=20, kde=True, color='red')

plt.subplot(1, 3, 3)
sns.histplot(df['MIN'], bins=20, kde=True, color='blue')

plt.subplots_adjust(top=0.85)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 5))
plt.suptitle("Pljevlja", fontsize=12, y=0.95)
plt.plot(df.index, df['TEMP'], label='TEMP', color='green')
plt.plot(df.index, df['MAX'], label='MAX', color='red')
plt.plot(df.index, df['MIN'], label='MIN', color='blue')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.grid()
plt.show()

# %%
df.to_csv("pvfinal.csv", index=False)
